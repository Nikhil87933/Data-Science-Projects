# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    recall_score,
    precision_score,
    roc_auc_score,
)
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import (
    RandomForestClassifier,
    AdaBoostClassifier, 
)
from lightgbm import LGBMClassifier  # LightGBM
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier, Pool, cv  # CatBoost
from sklearn.ensemble import ExtraTreesClassifier  # Extra Trees
import xgboost as xgb  # XGBoost
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score, recall_score, roc_auc_score
from sklearn.metrics import log_loss, roc_auc_score

# Initializing the LightGBM model with lower verbosity
lgbm_model = LGBMClassifier(verbosity=-1)  # -1 for minimal verbosity

# Initializing the CatBoost model with lower verbosity (0 to suppress output)
catboost_model = CatBoostClassifier(verbose=0)  # 0 to suppress output

import warnings

# Suppressing LightGBM and CatBoost warnings
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")
warnings.filterwarnings("ignore", category=UserWarning, module="catboost")
sns.set()
# %matplotlib inline
import os
sns.set()

# %%
data = pd.read_csv('C:/Users/Nikhil_Chamle/Desktop/Project_10_Cupom reco/Data.csv')

# %%
df = data.copy()

# %%
pd.set_option('display.max_columns', 50)

# %%
# dropping irrelvant columns on basis of null values and dropping null rows, duplicated values
df = df.drop(columns='car')
df = df.dropna()
df = df.drop_duplicates(ignore_index=True)

# %%
# Renaming column

df = df.rename(columns = {'Accept(Y/N?)': 'Accept'})

# %%
# Creating new column 'Age' 
# (below21,21,26) -> young
# (31, 36, 41, 46) -> mid_age
# (above50) -> older

df.loc[df['age'] == 'below21', 'Age'] = 'young' 
df.loc[df['age'] == '21', 'Age'] = 'young' 
df.loc[df['age'] == '26', 'Age'] = 'young' 
df.loc[df['age'] == '31', 'Age'] = 'mid_age' 
df.loc[df['age'] == '36', 'Age'] = 'mid_age' 
df.loc[df['age'] == '41', 'Age'] = 'mid_age' 
df.loc[df['age'] == '46', 'Age'] = 'mid_age'
df.loc[df['age'] == '50plus', 'Age'] = 'older'

# %%
# Creating new column 'Income' 

# below 49999 - low income
# above 50000 - mid income

# we will not go for high income as High income individuals wont only be attracted by coupons and for these going to food places may vary on several other factors, can be for mid income level too but for now lets consider earlir

df.loc[df['income'] == 'Less than $12500','Income'] = 'Low'
df.loc[df['income'] == '$12500 - $24999', 'Income'] = 'Low'
df.loc[df['income'] == '$25000 - $37499','Income'] = 'Low'
df.loc[df['income'] == '$37500 - $49999', 'Income'] = 'Low'
df.loc[df['income'] == '$50000 - $62499', 'Income'] = 'Mid'
df.loc[df['income'] == '$62500 - $74999', 'Income'] = 'Mid'
df.loc[df['income'] == '$75000 - $87499','Income'] = 'Mid'
df.loc[df['income'] == '$87500 - $99999', 'Income'] = 'Mid'
df.loc[df['income'] == '$100000 or More', 'Income'] = 'Mid'

# %%
# we will create new feature based on education

# criteria High school(low_education)<college(low_education)<1st_degree(mid_education)<High_degree(high_education)

# low_education < mid_eduction < high_education

#Creating new feature by using logic statement for durantion required to travel
 
df.loc[df['education'] == 'Some High School', 'Level_of_education'] = 'low_education' 
df.loc[df['education'] == 'High School Graduate', 'Level_of_education'] = 'low_education' 
df.loc[df['education'] == 'Some college - no degree', 'Level_of_education'] = 'low_education' 
df.loc[df['education'] == 'Associates degree', 'Level_of_education'] = 'mid_education' 
df.loc[df['education'] == 'Bachelors degree', 'Level_of_education'] = 'mid_education' 
df.loc[df['education'] == 'Graduate degree (Masters or Doctorate)', 'Level_of_education'] = 'high_education'

# %%
# creating new feature on basis of occupation and %acceptance of coupon

# criteria - =above 60% > High, 50-59.99% > Medium, below 49.99 > low acceptance

cross_tab = pd.crosstab(columns=[df['Accept']], index=[df['occupation']], margins=True, normalize='index')

# Calculate the acceptance percentage and categorize it
cross_tab['Acceptance%'] = cross_tab[1] * 100  # Calculate the acceptance percentage

# criteria for categorization
def categorize_acceptance(percentage):
    if percentage >= 60:
        return 'High'
    elif 50 <= percentage <= 59.99:
        return 'Medium'
    else:
        return 'Low'

# Applying the categorization function to the 'Acceptance%' column
cross_tab['Occupation_with_(1)%'] = cross_tab['Acceptance%'].apply(categorize_acceptance)

# Merging the 'Acceptance%' and 'Acceptance_Category' columns back into the 'df' DataFrame based on 'occupation'
df = df.merge(cross_tab[['Acceptance%', 'Occupation_with_(1)%']], left_on='occupation', right_index=True, how='left')

# %%
#Creating new feature by time required

df['Coupon_timeRequired_15to25'] = 0 
df.loc[(df['toCoupon_GEQ15min'] == 1) & (df['toCoupon_GEQ25min'] == 0), 'Coupon_timeRequired_15to25'] = 1
df.loc[df['toCoupon_GEQ15min'] == 0, 'Coupon_timeRequired_15to25'] = 0
df.loc[df['toCoupon_GEQ25min'] == 1, 'Coupon_timeRequired_15to25'] = 2

# %%
# we want to know if we offer a coupon to an individual does he accept it if he is the regular visitor to that category of place

Relative_coupon_Accepted_count = []

for i in range(df.shape[0]):
    if df['coupon'].iloc[i] == 'Restaurant(<20)':
        Relative_coupon_Accepted_count.append(df['RestaurantLessThan20'].iloc[i])
    elif df['coupon'].iloc[i] == 'Coffee House':
        Relative_coupon_Accepted_count.append(df['CoffeeHouse'].iloc[i])
    elif df['coupon'].iloc[i] == 'Carry out & Take away':
        Relative_coupon_Accepted_count.append(df['CarryAway'].iloc[i])
    elif df['coupon'].iloc[i] == 'Bar':
        Relative_coupon_Accepted_count.append(df['Bar'].iloc[i])
    elif df['coupon'].iloc[i] == 'Restaurant(20-50)':
        Relative_coupon_Accepted_count.append(df['Restaurant20To50'].iloc[i])

df['Relative_coupon_Accepted_count'] = Relative_coupon_Accepted_count

# %%
# dropping columns

df = df.drop(['Bar', 'CoffeeHouse', 'CarryAway',
       'RestaurantLessThan20', 'Restaurant20To50', 'age', 'income', 'education', 'occupation', 'Acceptance%', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min', 'direction_same', 'direction_opp', 'toCoupon_GEQ5min'], axis=1)

# %%
categorical_features = ['destination', 'passanger', 'weather', 'temperature', 'coupon',
       'expiration', 'gender', 'maritalStatus', 'has_children',
       'Age', 'Income', 'Level_of_education', 'Occupation_with_(1)%',
       'Coupon_timeRequired_15to25', 'Relative_coupon_Accepted_count']

# %%
# Apply label encoding to each categorical column
for col in categorical_features:
    df[col] = label_encoder.fit_transform(df[col])

# %%
y = df['Accept'].astype(int)  # Target variable
X = df.drop(columns=['Accept']).astype(int)  # Features

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size =0.2)

# %%
models = []
models.append(("LR", LogisticRegression()))
models.append(("LDA", LinearDiscriminantAnalysis()))
models.append(("KNN", KNeighborsClassifier()))
models.append(("CART", DecisionTreeClassifier()))
models.append(("NB", GaussianNB()))
models.append(("SVM", SVC()))
models.append(("RF", RandomForestClassifier()))
models.append(("ExtraTrees", ExtraTreesClassifier()))  # Extra Trees
models.append(("AdaBoost", AdaBoostClassifier()))  # AdaBoost
models.append(("XGBoost", xgb.XGBClassifier()))  # XGBoost

results = []
names = []

for name, model in models:
    kfold = KFold(n_splits=10)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring="accuracy")
    results.append(cv_results)
    names.append(name)
    msg = "%s Accuracy: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)

    # Calculating training accuracy
    model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    print(f"Training Accuracy for {name}: {train_accuracy}")
    print()

    # Calculating test accuracy
    y_pred = model.predict(X_test)
    test_accuracy = accuracy_score(y_test, y_pred)
    print(f"Test Accuracy for {name}: {test_accuracy}")

    # Calculating additional metrics
    print(f"Confusion Matrix for {name}:\n{confusion_matrix(y_test, y_pred)}")
    print()
    print(f"Classification Report for {name}:\n{classification_report(y_test, y_pred)}")
    print()
    print(f"Recall for {name}: {recall_score(y_test, y_pred)}")
    print()
    print(f"Precision for {name}: {precision_score(y_test, y_pred)}")
    print()
    print(f"ROC AUC for {name}: {roc_auc_score(y_test, y_pred)}")
    print("----------------------------------------------------------------------------")
# Out:
# LR Accuracy: 0.679029 (0.004855)
# Training Accuracy for LR: 0.6797711137013882
#
# Test Accuracy for LR: 0.661864406779661
# Confusion Matrix for LR:
# [[ 554  477]
#  [ 321 1008]]
#
# Classification Report for LR:
#               precision    recall  f1-score   support
#
#            0       0.63      0.54      0.58      1031
#            1       0.68      0.76      0.72      1329
#
#     accuracy                           0.66      2360
#    macro avg       0.66      0.65      0.65      2360
# weighted avg       0.66      0.66      0.66      2360
#
#
# Recall for LR: 0.7584650112866818
#
# Precision for LR: 0.6787878787878788
#
# ROC AUC for LR: 0.6479036986598298
# ----------------------------------------------------------------------------
# LDA Accuracy: 0.680089 (0.005066)
# Training Accuracy for LDA: 0.68040690897531
#
# Test Accuracy for LDA: 0.6610169491525424
# Confusion Matrix for LDA:
# [[ 560  471]
#  [ 329 1000]]
#
# Classification Report for LDA:
#               precision    recall  f1-score   support
#
#            0       0.63      0.54      0.58      1031
#            1       0.68      0.75      0.71      1329
#
#     accuracy                           0.66      2360
#    macro avg       0.65      0.65      0.65      2360
# weighted avg       0.66      0.66      0.66      2360
#
#
# Recall for LDA: 0.7524454477050414
#
# Precision for LDA: 0.6798096532970768
#
# ROC AUC for LDA: 0.6478037131832675
# ----------------------------------------------------------------------------
# KNN Accuracy: 0.684962 (0.015318)
# Training Accuracy for KNN: 0.7889159690579634
#
# Test Accuracy for KNN: 0.6707627118644067
# Confusion Matrix for KNN:
# [[598 433]
#  [344 985]]
#
# Classification Report for KNN:
#               precision    recall  f1-score   support
#
#            0       0.63      0.58      0.61      1031
#            1       0.69      0.74      0.72      1329
#
#     accuracy                           0.67      2360
#    macro avg       0.66      0.66      0.66      2360
# weighted avg       0.67      0.67      0.67      2360
#
#
# Recall for KNN: 0.7411587659894657
#
# Precision for KNN: 0.6946403385049366
#
# ROC AUC for KNN: 0.6605890823157804
# ----------------------------------------------------------------------------
# CART Accuracy: 0.647985 (0.018147)
# Training Accuracy for CART: 0.9619582494436791
#
# Test Accuracy for CART: 0.6402542372881356
# Confusion Matrix for CART:
# [[640 391]
#  [458 871]]
#
# Classification Report for CART:
#               precision    recall  f1-score   support
#
#            0       0.58      0.62      0.60      1031
#            1       0.69      0.66      0.67      1329
#
#     accuracy                           0.64      2360
#    macro avg       0.64      0.64      0.64      2360
# weighted avg       0.64      0.64      0.64      2360
#
#
# Recall for CART: 0.6553799849510911
#
# Precision for CART: 0.6901743264659271
#
# ROC AUC for CART: 0.6380682659963991
# ----------------------------------------------------------------------------
# NB Accuracy: 0.675319 (0.010295)
# Training Accuracy for NB: 0.6776517961216488
#
# Test Accuracy for NB: 0.648728813559322
# Confusion Matrix for NB:
# [[558 473]
#  [356 973]]
#
# Classification Report for NB:
#               precision    recall  f1-score   support
#
#            0       0.61      0.54      0.57      1031
#            1       0.67      0.73      0.70      1329
#
#     accuracy                           0.65      2360
#    macro avg       0.64      0.64      0.64      2360
# weighted avg       0.65      0.65      0.65      2360
#
#
# Recall for NB: 0.7321294206170053
#
# Precision for NB: 0.6728907330567082
#
# ROC AUC for NB: 0.6366757675344968
# ----------------------------------------------------------------------------
# SVM Accuracy: 0.717176 (0.007358)
# Training Accuracy for SVM: 0.739747801208011
#
# Test Accuracy for SVM: 0.6944915254237288
# Confusion Matrix for SVM:
# [[ 552  479]
#  [ 242 1087]]
#
# Classification Report for SVM:
#               precision    recall  f1-score   support
#
#            0       0.70      0.54      0.60      1031
#            1       0.69      0.82      0.75      1329
#
#     accuracy                           0.69      2360
#    macro avg       0.69      0.68      0.68      2360
# weighted avg       0.69      0.69      0.69      2360
#
#
# Recall for SVM: 0.81790820165538
#
# Precision for SVM: 0.6941251596424011
#
# ROC AUC for SVM: 0.6766553617394262
# ----------------------------------------------------------------------------
# RF Accuracy: 0.704570 (0.011862)
# Training Accuracy for RF: 0.9619582494436791
#
# Test Accuracy for RF: 0.6847457627118644
# Confusion Matrix for RF:
# [[ 594  437]
#  [ 307 1022]]
#
# Classification Report for RF:
#               precision    recall  f1-score   support
#
#            0       0.66      0.58      0.61      1031
#            1       0.70      0.77      0.73      1329
#
#     accuracy                           0.68      2360
#    macro avg       0.68      0.67      0.67      2360
# weighted avg       0.68      0.68      0.68      2360
#
#
# Recall for RF: 0.7689992475545523
#
# Precision for RF: 0.7004797806716929
#
# ROC AUC for RF: 0.6725694588888183
# ----------------------------------------------------------------------------
# ExtraTrees Accuracy: 0.697680 (0.011075)
# Training Accuracy for ExtraTrees: 0.9619582494436791
#
# Test Accuracy for ExtraTrees: 0.686864406779661
# Confusion Matrix for ExtraTrees:
# [[ 609  422]
#  [ 317 1012]]
#
# Classification Report for ExtraTrees:
#               precision    recall  f1-score   support
#
#            0       0.66      0.59      0.62      1031
#            1       0.71      0.76      0.73      1329
#
#     accuracy                           0.69      2360
#    macro avg       0.68      0.68      0.68      2360
# weighted avg       0.68      0.69      0.68      2360
#
#
# Recall for ExtraTrees: 0.7614747930775019
#
# Precision for ExtraTrees: 0.705718270571827
#
# ROC AUC for ExtraTrees: 0.6760817224359381
# ----------------------------------------------------------------------------
# AdaBoost Accuracy: 0.712514 (0.008067)
# Training Accuracy for AdaBoost: 0.7133622973402565
#
# Test Accuracy for AdaBoost: 0.690677966101695
# Confusion Matrix for AdaBoost:
# [[ 569  462]
#  [ 268 1061]]
#
# Classification Report for AdaBoost:
#               precision    recall  f1-score   support
#
#            0       0.68      0.55      0.61      1031
#            1       0.70      0.80      0.74      1329
#
#     accuracy                           0.69      2360
#    macro avg       0.69      0.68      0.68      2360
# weighted avg       0.69      0.69      0.69      2360
#
#
# Recall for AdaBoost: 0.7983446200150489
#
# Precision for AdaBoost: 0.6966513460275772
#
# ROC AUC for AdaBoost: 0.6751179938096583
# ----------------------------------------------------------------------------
# XGBoost Accuracy: 0.730741 (0.012029)
# Training Accuracy for XGBoost: 0.8576878245205044
#
# Test Accuracy for XGBoost: 0.7067796610169491
# Confusion Matrix for XGBoost:
# [[ 625  406]
#  [ 286 1043]]
#
# Classification Report for XGBoost:
#               precision    recall  f1-score   support
#
#            0       0.69      0.61      0.64      1031
#            1       0.72      0.78      0.75      1329
#
#     accuracy                           0.71      2360
#    macro avg       0.70      0.70      0.70      2360
# weighted avg       0.71      0.71      0.70      2360
#
#
# Recall for XGBoost: 0.7848006019563581
#
# Precision for XGBoost: 0.7198067632850241
#
# ROC AUC for XGBoost: 0.6955040837133877
# ----------------------------------------------------------------------------

# %%
models = []
models.append(("LGBM", LGBMClassifier()))  # LightGBM

results = []
names = []

for name, model in models:
    kfold = KFold(n_splits=10)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring="accuracy")
    results.append(cv_results)
    names.append(name)
    msg = "%s Accuracy: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)

    # Calculating training accuracy
    model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    print(f"Training Accuracy for {name}: {train_accuracy}")
    print()

    # Calculating test accuracy
    y_pred = model.predict(X_test)
    test_accuracy = accuracy_score(y_test, y_pred)
    print(f"Test Accuracy for {name}: {test_accuracy}")

    # Calculating additional metrics
    print(f"Confusion Matrix for {name}:\n{confusion_matrix(y_test, y_pred)}")
    print()
    print(f"Classification Report for {name}:\n{classification_report(y_test, y_pred)}")
    print()
    print(f"Recall for {name}: {recall_score(y_test, y_pred)}")
    print()
    print(f"Precision for {name}: {precision_score(y_test, y_pred)}")
    print()
    print(f"ROC AUC for {name}: {roc_auc_score(y_test, y_pred)}")
    print("----------------------------------------------------------------------------")
# Out:
# [LightGBM] [Info] Number of positive: 4819, number of negative: 3674
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000211 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 8493, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.567408 -> initscore=0.271285
# [LightGBM] [Info] Start training from score 0.271285
# [LightGBM] [Info] Number of positive: 4820, number of negative: 3673
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000198 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 8493, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.567526 -> initscore=0.271765
# [LightGBM] [Info] Start training from score 0.271765
# [LightGBM] [Info] Number of positive: 4830, number of negative: 3663
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000214 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 8493, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.568704 -> initscore=0.276564
# [LightGBM] [Info] Start training from score 0.276564
# [LightGBM] [Info] Number of positive: 4830, number of negative: 3663
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000171 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 8493, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.568704 -> initscore=0.276564
# [LightGBM] [Info] Start training from score 0.276564
# [LightGBM] [Info] Number of positive: 4825, number of negative: 3668
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000220 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 8493, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.568115 -> initscore=0.274164
# [LightGBM] [Info] Start training from score 0.274164
# [LightGBM] [Info] Number of positive: 4815, number of negative: 3678
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 8493, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.566937 -> initscore=0.269367
# [LightGBM] [Info] Start training from score 0.269367
# [LightGBM] [Info] Number of positive: 4818, number of negative: 3675
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000143 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 8493, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.567291 -> initscore=0.270806
# [LightGBM] [Info] Start training from score 0.270806
# [LightGBM] [Info] Number of positive: 4805, number of negative: 3689
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 8494, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.565693 -> initscore=0.264302
# [LightGBM] [Info] Start training from score 0.264302
# [LightGBM] [Info] Number of positive: 4825, number of negative: 3669
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 8494, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.568048 -> initscore=0.273892
# [LightGBM] [Info] Start training from score 0.273892
# [LightGBM] [Info] Number of positive: 4826, number of negative: 3668
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000185 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 8494, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.568166 -> initscore=0.274371
# [LightGBM] [Info] Start training from score 0.274371
# LGBM Accuracy: 0.735722 (0.006113)
# [LightGBM] [Info] Number of positive: 5357, number of negative: 4080
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000211 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 9437, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.567659 -> initscore=0.272307
# [LightGBM] [Info] Start training from score 0.272307
# Training Accuracy for LGBM: 0.7877503443891067
#
# Test Accuracy for LGBM: 0.7161016949152542
# Confusion Matrix for LGBM:
# [[ 612  419]
#  [ 251 1078]]
#
# Classification Report for LGBM:
#               precision    recall  f1-score   support
#
#            0       0.71      0.59      0.65      1031
#            1       0.72      0.81      0.76      1329
#
#     accuracy                           0.72      2360
#    macro avg       0.71      0.70      0.70      2360
# weighted avg       0.72      0.72      0.71      2360
#
#
# Recall for LGBM: 0.8111361926260346
#
# Precision for LGBM: 0.7201068804275217
#
# ROC AUC for LGBM: 0.7023673203673335
# ----------------------------------------------------------------------------

# %%
models = []
models.append(("CatBoost", CatBoostClassifier()))

results = []
names = []

for name, model in models:
    kfold = KFold(n_splits=10)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring="accuracy")
    results.append(cv_results)
    names.append(name)
    msg = "%s Accuracy: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)

    # Calculating training accuracy
    model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    print(f"Training Accuracy for {name}: {train_accuracy}")
    print()

    # Calculating test accuracy
    y_pred = model.predict(X_test)
    test_accuracy = accuracy_score(y_test, y_pred)
    print(f"Test Accuracy for {name}: {test_accuracy}")

    # Calculating additional metrics
    print(f"Confusion Matrix for {name}:\n{confusion_matrix(y_test, y_pred)}")
    print()
    print(f"Classification Report for {name}:\n{classification_report(y_test, y_pred)}")
    print()
    print(f"Recall for {name}: {recall_score(y_test, y_pred)}")
    print()
    print(f"Precision for {name}: {precision_score(y_test, y_pred)}")
    print()
    print(f"ROC AUC for {name}: {roc_auc_score(y_test, y_pred)}")
    print("----------------------------------------------------------------------------")
# Out:
# Learning rate set to 0.025683
# 0:	learn: 0.6875206	total: 147ms	remaining: 2m 26s
# 1:	learn: 0.6821093	total: 150ms	remaining: 1m 15s
# 2:	learn: 0.6771721	total: 154ms	remaining: 51.2s
# 3:	learn: 0.6719008	total: 158ms	remaining: 39.3s
# 4:	learn: 0.6669840	total: 161ms	remaining: 32.1s
# 5:	learn: 0.6623590	total: 165ms	remaining: 27.4s
# 6:	learn: 0.6579173	total: 169ms	remaining: 23.9s
# 7:	learn: 0.6538384	total: 172ms	remaining: 21.4s
# 8:	learn: 0.6502864	total: 176ms	remaining: 19.4s
# 9:	learn: 0.6466346	total: 180ms	remaining: 17.8s
# 10:	learn: 0.6432684	total: 184ms	remaining: 16.6s
# 11:	learn: 0.6399956	total: 188ms	remaining: 15.5s
# 12:	learn: 0.6365154	total: 191ms	remaining: 14.5s
# 526:	learn: 0.4632426	total: 1.61s	remaining: 1.45s
# 527:	learn: 0.4630007	total: 1.62s	remaining: 1.45s
# 528:	learn: 0.4629102	total: 1.62s	remaining: 1.44s
# 529:	learn: 0.4627418	total: 1.62s	remaining: 1.44s
# 530:	learn: 0.4625636	total: 1.63s	remaining: 1.44s
# 531:	learn: 0.4623661	total: 1.63s	remaining: 1.43s
# 532:	learn: 0.4621721	total: 1.63s	remaining: 1.43s
# 533:	learn: 0.4620780	total: 1.64s	remaining: 1.43s
# 534:	learn: 0.4619045	total: 1.64s	remaining: 1.42s
# 535:	learn: 0.4617505	total: 1.64s	remaining: 1.42s
# 536:	learn: 0.4615943	total: 1.64s	remaining: 1.42s
# 537:	learn: 0.4615199	total: 1.65s	remaining: 1.41s
# 538:	learn: 0.4613843	total: 1.65s	remaining: 1.41s
# 539:	learn: 0.4612633	total: 1.65s	remaining: 1.41s
# 540:	learn: 0.4611784	total: 1.66s	remaining: 1.41s
# 541:	learn: 0.4610754	total: 1.66s	remaining: 1.4s
# 542:	learn: 0.4609352	total: 1.66s	remaining: 1.4s
# 543:	learn: 0.4607959	total: 1.66s	remaining: 1.4s
# 544:	learn: 0.4606191	total: 1.67s	remaining: 1.39s
# 545:	learn: 0.4604941	total: 1.67s	remaining: 1.39s
# 546:	learn: 0.4604158	total: 1.67s	remaining: 1.38s
# 547:	learn: 0.4602299	total: 1.68s	remaining: 1.38s
# 548:	learn: 0.4600600	total: 1.68s	remaining: 1.38s
# 549:	learn: 0.4598765	total: 1.68s	remaining: 1.37s
# 550:	learn: 0.4597523	total: 1.68s	remaining: 1.37s
# 551:	learn: 0.4596422	total: 1.69s	remaining: 1.37s
# 552:	learn: 0.4595104	total: 1.69s	remaining: 1.36s
# 553:	learn: 0.4593455	total: 1.69s	remaining: 1.36s
# 554:	learn: 0.4592051	total: 1.69s	remaining: 1.36s
# 555:	learn: 0.4589764	total: 1.7s	remaining: 1.35s
# 556:	learn: 0.4588135	total: 1.7s	remaining: 1.35s
# 557:	learn: 0.4586955	total: 1.7s	remaining: 1.35s
# 558:	learn: 0.4585977	total: 1.7s	remaining: 1.34s
# 559:	learn: 0.4584600	total: 1.71s	remaining: 1.34s
# 560:	learn: 0.4583358	total: 1.71s	remaining: 1.34s
# 561:	learn: 0.4581851	total: 1.71s	remaining: 1.33s
# 562:	learn: 0.4580086	total: 1.72s	remaining: 1.33s
# 563:	learn: 0.4578958	total: 1.72s	remaining: 1.33s
# 564:	learn: 0.4577421	total: 1.72s	remaining: 1.32s
# 565:	learn: 0.4576294	total: 1.72s	remaining: 1.32s
# 566:	learn: 0.4575009	total: 1.73s	remaining: 1.32s
# 567:	learn: 0.4573320	total: 1.73s	remaining: 1.31s
# 568:	learn: 0.4572154	total: 1.73s	remaining: 1.31s
# 569:	learn: 0.4570783	total: 1.73s	remaining: 1.31s
# 570:	learn: 0.4568992	total: 1.74s	remaining: 1.3s
# 571:	learn: 0.4567538	total: 1.74s	remaining: 1.3s
# 964:	learn: 0.4191816	total: 2.46s	remaining: 89.1ms
# 965:	learn: 0.4190913	total: 2.46s	remaining: 86.6ms
# 966:	learn: 0.4189717	total: 2.46s	remaining: 84.1ms
# 967:	learn: 0.4189174	total: 2.46s	remaining: 81.5ms
# 968:	learn: 0.4188248	total: 2.47s	remaining: 79ms
# 969:	learn: 0.4187490	total: 2.47s	remaining: 76.4ms
# 970:	learn: 0.4185850	total: 2.47s	remaining: 73.9ms
# 971:	learn: 0.4184779	total: 2.48s	remaining: 71.3ms
# 972:	learn: 0.4183854	total: 2.48s	remaining: 68.8ms
# 973:	learn: 0.4183125	total: 2.48s	remaining: 66.3ms
# 974:	learn: 0.4182121	total: 2.48s	remaining: 63.7ms
# 975:	learn: 0.4181577	total: 2.49s	remaining: 61.2ms
# 976:	learn: 0.4181089	total: 2.49s	remaining: 58.6ms
# 977:	learn: 0.4180505	total: 2.49s	remaining: 56.1ms
# 978:	learn: 0.4179617	total: 2.5s	remaining: 53.5ms
# 979:	learn: 0.4178551	total: 2.5s	remaining: 51ms
# 980:	learn: 0.4177823	total: 2.5s	remaining: 48.4ms
# 981:	learn: 0.4177100	total: 2.5s	remaining: 45.9ms
# 982:	learn: 0.4176437	total: 2.51s	remaining: 43.3ms
# 983:	learn: 0.4175838	total: 2.51s	remaining: 40.8ms
# 984:	learn: 0.4175324	total: 2.51s	remaining: 38.2ms
# 985:	learn: 0.4174490	total: 2.51s	remaining: 35.7ms
# 986:	learn: 0.4173708	total: 2.52s	remaining: 33.1ms
# 987:	learn: 0.4172819	total: 2.52s	remaining: 30.6ms
# 988:	learn: 0.4171972	total: 2.52s	remaining: 28ms
# 989:	learn: 0.4171023	total: 2.52s	remaining: 25.5ms
# 990:	learn: 0.4170029	total: 2.53s	remaining: 22.9ms
# 991:	learn: 0.4169008	total: 2.53s	remaining: 20.4ms
# 992:	learn: 0.4168308	total: 2.53s	remaining: 17.8ms
# 993:	learn: 0.4167668	total: 2.53s	remaining: 15.3ms
# 994:	learn: 0.4166483	total: 2.54s	remaining: 12.7ms
# 995:	learn: 0.4165382	total: 2.54s	remaining: 10.2ms
# 996:	learn: 0.4164815	total: 2.54s	remaining: 7.65ms
# 997:	learn: 0.4163910	total: 2.54s	remaining: 5.1ms
# 998:	learn: 0.4163431	total: 2.55s	remaining: 2.55ms
# 999:	learn: 0.4162447	total: 2.55s	remaining: 0us
# Training Accuracy for CatBoost: 0.818162551658366
#
# Test Accuracy for CatBoost: 0.7266949152542372
# Confusion Matrix for CatBoost:
# [[ 635  396]
#  [ 249 1080]]
#
# Classification Report for CatBoost:
#               precision    recall  f1-score   support
#
#            0       0.72      0.62      0.66      1031
#            1       0.73      0.81      0.77      1329
#
#     accuracy                           0.73      2360
#    macro avg       0.73      0.71      0.72      2360
# weighted avg       0.73      0.73      0.72      2360
#
#
# Recall for CatBoost: 0.8126410835214447
#
# Precision for CatBoost: 0.7317073170731707
#
# ROC AUC for CatBoost: 0.7142739850196942
# ----------------------------------------------------------------------------
